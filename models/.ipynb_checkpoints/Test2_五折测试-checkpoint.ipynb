# %%
import numpy as np
import pandas as pd
from LAY2 import  ensemble_models
from utils import Args
from utils import metric_r, metric_c
# Out:
# Skipped loading some Tensorflow models, missing a dependency. No module named 'tensorflow'
# Skipped loading modules with pytorch-lightning dependency, missing a dependency. No module named 'pytorch_lightning'
# Skipped loading some Jax models, missing a dependency. No module named 'jax'

# %%
import sys
sys.path.append("../DB")

from DB import db

# %%
train_2 = pd.read_excel("../DataBase/test2.xlsx",sheet_name=0)[['cas','smiles','log10']]
train_2.columns = ['cas','smiles','LogLD']
test_2 = pd.read_excel("../DataBase/test2.xlsx",sheet_name=1)[['cas','log10','smiles']]
test_2.columns = ['cas','smiles','LogLD']

# %%
train_2.to_csv('train.csv')
test_2.to_csv('test.csv')

# %%
train_2.shape
# Out:
# (6714, 3)

# %%
# 加载数据集
data_loader = db('train.csv')
# data_loader.get_data()
data_loader.data = data_loader.data.iloc[:100, :]
# 五折切割
# train, test = next(data_loader.get_folds())
# Out:
# data already finished size =6714

# %%
for i,(train, test) in enumerate(data_loader.get_folds()):
    # 定义参数类
    args = Args(train, test, 
                # AFP=True, 
                RF=True, 
                MPNN=True,
                SVR=True, 
                GCN= False,
                save_r=True, 
                plot=True,
                GAT=True, 
                DNN=True,
                AD_FP=False)
    # 实例化集成模型
    eb = ensemble_models()
    # 训练第一层模型，save选择是否保存模型
    eb.Lay1_models_train(args ,save=True)
    # 保存结果
    df_train_L1 = eb.L1_train_df
    df_test_L1 = eb.L1_test_df
    df_train_L1.to_csv("df_train_L1_fold{}.csv".format(i))
    df_test_L1.to_csv("df_test_L1_fold{}.csv".format(i))

    # 训练第二层模型
    args.model_lis_L2 = [True for i in range(3)]
    eb.Lay2_models_train(args,save=True)
    # 保存结果
    df_train_L2 = eb.L2_train_df
    df_test_L2 = eb.L2_test_df
    df_train_L2.to_csv("df_train_L2_fold{}.csv".format(i))
    df_test_L2.to_csv("df_test_L2_fold{}.csv".format(i))
    # 训练第三层模型，
    # 第三层模型为非负最小二乘，只有保存权重和偏置
    eb.Lay3_models_train(args)
    # 保存结果
    df_train_L3 = eb.L3_train_df
    df_test_L3 = eb.L3_test_df
    print(eb.lis_coef)
    df_train_L3.to_csv("df_train_L3_fold{}.csv".format(i))
    df_test_L3.to_csv("df_test_L3_fold{}.csv".format(i))
# Out:
# fold0
# size of train is(80, 3) ,test is (20, 3)
# start training GAT
# 完成转换,start fitting
# test_rmse  is  1.4536850224747804
# test_mae  is  1.566519704010873
# test_R2  is  -6.8158806341221005
# Command line
# python E:\Program Files\anaconda\envs\Miku\lib\site-packages\ipykernel_launcher.py -f C:\Users\donkey\AppData\Roaming\jupyter\runtime\kernel-dbd37644-e854-4293-97ac-e361e92c7dad.json
# Args
# {'activation': 'ReLU',
#  'adding_h': False,
#  'aggregation': 'mean',
#  'aggregation_norm': 100,
#  'atom_descriptor_scaling': True,
#  'atom_descriptors': None,
#  'atom_descriptors_path': None,
#  'atom_descriptors_size': 0,
#  'atom_features_size': 0,
#  'atom_messages': False,
#  'batch_size': 50,
#  'bias': False,
#  'bias_solvent': False,
#  'bond_feature_scaling': True,
#  'bond_features_path': None,
#  'bond_features_size': 0,
#  'cache_cutoff': 10000,
#  'checkpoint_dir': None,
#  'checkpoint_frzn': None,
#  'checkpoint_path': None,
#  'checkpoint_paths': None,
#  'class_balance': False,
#  'config_path': None,
#  'crossval_index_dir': None,
#  'crossval_index_file': None,
#  'crossval_index_sets': None,
#  'cuda': True,
#  'data_path': 'model_checkpoint/MPNN/train.csv',
#  'data_weights_path': None,
#  'dataset_type': 'regression',
#  'depth': 3,
#  'depth_solvent': 3,
#  'device': device(type='cuda'),
#  'dropout': 0.0,
#  'empty_cache': False,
#  'ensemble_size': 1,
#  'epochs': 25,
#  'evidential_regularization': 0,
#  'explicit_h': False,
#  'extra_metrics': [],
#  'features_generator': None,
#  'features_only': False,
#  'features_path': None,
#  'features_scaling': True,
#  'features_size': None,
#  'ffn_hidden_size': 300,
#  'ffn_num_layers': 2,
#  'final_lr': 0.0001,
#  'folds_file': None,
#  'freeze_first_only': False,
#  'frzn_ffn_layers': 0,
#  'gpu': None,
#  'grad_clip': None,
#  'hidden_size': 300,
#  'hidden_size_solvent': 300,
#  'ignore_columns': None,
#  'init_lr': 0.0001,
#  'log_frequency': 10,
#  'loss_function': 'mse',
#  'max_data_size': None,
#  'max_lr': 0.001,
#  'metric': 'rmse',
#  'metrics': ['rmse'],
#  'minimize_score': True,
#  'mpn_shared': False,
#  'multiclass_num_classes': 3,
#  'no_atom_descriptor_scaling': False,
#  'no_bond_features_scaling': False,
#  'no_cache_mol': False,
#  'no_cuda': False,
#  'no_features_scaling': False,
#  'num_folds': 1,
#  'num_lrs': 1,
#  'num_tasks': 1,
#  'num_workers': 8,
#  'number_of_molecules': 1,
#  'overwrite_default_atom_features': False,
#  'overwrite_default_bond_features': False,
#  'phase_features_path': None,
#  'pytorch_seed': 0,
#  'quiet': False,
#  'reaction': False,
#  'reaction_mode': 'reac_diff',
#  'reaction_solvent': False,
#  'resume_experiment': False,
#  'save_dir': 'model_checkpoint/MPNN/test_checkpoints_reg',
#  'save_preds': False,
#  'save_smiles_splits': False,
#  'seed': 0,
#  'separate_test_atom_descriptors_path': None,
#  'separate_test_bond_features_path': None,
#  'separate_test_features_path': None,
#  'separate_test_path': 'model_checkpoint/MPNN/test.csv',
#  'separate_test_phase_features_path': None,
#  'separate_val_atom_descriptors_path': None,
#  'separate_val_bond_features_path': None,
#  'separate_val_features_path': None,
#  'separate_val_path': 'model_checkpoint/MPNN/test.csv',
#  'separate_val_phase_features_path': None,
#  'show_individual_scores': False,
#  'smiles_columns': ['smiles'],
#  'spectra_activation': 'exp',
#  'spectra_phase_mask_path': None,
#  'spectra_target_floor': 1e-08,
#  'split_key_molecule': 0,
#  'split_sizes': [1.0, 0.0, 0.0],
#  'split_type': 'random',
#  'target_columns': None,
#  'target_weights': None,
#  'task_names': ['LogLD'],
#  'test': False,
#  'test_fold_index': None,
#  'train_data_size': None,
#  'undirected': False,
#  'use_input_features': False,
#  'val_fold_index': None,
#  'warmup_epochs': 2.0}
# 异常化合物（不能转化为图的化合物）情况：训练集共0个，测试集共0个
# ============GAT over============
# start training MPNN
# Setting molecule featurization parameters to default.
# Loading data
# 80it [00:00, 80427.69it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 80/80 [00:00<00:00, 81880.02it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 80/80 [00:00<00:00, 6664.24it/s]
# Number of tasks = 1
# Fold 0
# Splitting data with seed 0
# 20it [00:00, 20111.74it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 20/20 [00:00<00:00, 19892.36it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 20/20 [00:00<00:00, 6694.28it/s]
# 20it [00:00, ?it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 20/20 [00:00<?, ?it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 20/20 [00:00<?, ?it/s]
# Total size = 80 | train size = 80 | val size = 20 | test size = 20
# Fitting scaler
# Building model 0
# MoleculeModel(
#   (encoder): MPN(
#     (encoder): ModuleList(
#       (0): MPNEncoder(
#         (dropout_layer): Dropout(p=0.0, inplace=False)
#         (act_func): ReLU()
#         (W_i): Linear(in_features=147, out_features=300, bias=False)
#         (W_h): Linear(in_features=300, out_features=300, bias=False)
#         (W_o): Linear(in_features=433, out_features=300, bias=True)
#       )
#     )
#   )
#   (ffn): Sequential(
#     (0): Dropout(p=0.0, inplace=False)
#     (1): Linear(in_features=300, out_features=300, bias=True)
#     (2): ReLU()
#     (3): Dropout(p=0.0, inplace=False)
#     (4): Linear(in_features=300, out_features=1, bias=True)
#   )
# )
# Number of parameters = 355,201
# Moving model to cuda
#   0%|                                                                                           | 0/25 [00:00<?, ?it/s]Epoch 0
#
#   0%|                                                                                            | 0/2 [00:00<?, ?it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00, 16.26it/s]
#
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
#                                                                                                                        Validation rmse = 0.868733
#   4%|███▎                                                                               | 1/25 [00:00<00:05,  4.63it/s]Epoch 1
#
#   0%|                                                                                            | 0/2 [00:00<?, ?it/s]
#
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
#                                                                                                                        Validation rmse = 0.613172
#   8%|██████▋                                                                            | 2/25 [00:00<00:04,  5.34it/s]Epoch 2
#
#   0%|                                                                                            | 0/2 [00:00<?, ?it/s]
#
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
#                                                                                                                        Validation rmse = 0.684267
#  12%|█████████▉                                                                         | 3/25 [00:00<00:03,  6.50it/s]Epoch 3
#
#   0%|                                                                                            | 0/2 [00:00<?, ?it/s]
#
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
#                                                                                                                        Validation rmse = 0.630558
#  16%|█████████████▎                                                                     | 4/25 [00:00<00:02,  7.20it/s]Epoch 4
#
#   0%|                                                                                            | 0/2 [00:00<?, ?it/s]
#
#   0%|                                                                                            | 0/1 [00:00<?, ?it/s]
#                                                                                                                        Validation rmse = 0.608640
#  20%|████████████████▌                                                                  | 5/25 [00:00<00:02,  7.63it/s]Epoch 5
#
#   0%|                                                                                            | 0/2 [00:00<?, ?it/s]
#
#   0%|
# <b>limit_output extension: Maximum message size of 10000 exceeded with 10024 characters</b>
# ---------------------------------------------------------------------------
# BrokenPipeError                           Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_51168\3131101742.py in <module>
#      15     eb = ensemble_models()
#      16     # 训练第一层模型，save选择是否保存模型
# ---> 17     eb.Lay1_models_train(args ,save=True)
#      18     # 保存结果
#      19     df_train_L1 = eb.L1_train_df
#
# E:\jupyter_files\科研\Stacking_model\models\LAY2.py in Lay1_models_train(self, Args, save)
#     248             ]
#     249             args = chemprop.args.PredictArgs().parse_args(arguments)
# --> 250             preds_train = chemprop.train.make_predictions(args=args)
#     251             recorder_MPNN['train_pre'] = preds
#     252             if plot:
#
# E:\Program Files\anaconda\envs\Miku\lib\site-packages\chemprop\utils.py in wrap(*args, **kwargs)
#     538         def wrap(*args, **kwargs) -> Any:
#     539             start_time = time()
# --> 540             result = func(*args, **kwargs)
#     541             delta = timedelta(seconds=round(time() - start_time))
#     542             info = logging.getLogger(logger_name).info if logger_name is not None else print
#
# E:\Program Files\anaconda\envs\Miku\lib\site-packages\chemprop\train\make_predictions.py in make_predictions(args, smiles, model_objects, calibrator, return_invalid_smiles, return_index_dict, return_uncertainty)
#     464             num_models=num_models,
#     465             calibrator=calibrator,
# --> 466             return_invalid_smiles=return_invalid_smiles,
#     467         )
#     468
#
# E:\Program Files\anaconda\envs\Miku\lib\site-packages\chemprop\train\make_predictions.py in predict_and_save(args, train_args, test_data, task_names, num_tasks, test_data_loader, full_data, full_to_valid_indices, models, scalers, num_models, calibrator, return_invalid_smiles, save_results)
#     168         dropout_sampling_size=args.dropout_sampling_size,
#     169         individual_ensemble_predictions=args.individual_ensemble_predictions,
# --> 170         spectra_phase_mask=getattr(train_args, "spectra_phase_mask", None),
#     171     )
#     172
#
# E:\Program Files\anaconda\envs\Miku\lib\site-packages\chemprop\uncertainty\uncertainty_estimator.py in __init__(self, test_data, test_data_loader, models, scalers, num_models, uncertainty_method, dataset_type, loss_function, uncertainty_dropout_p, dropout_sampling_size, individual_ensemble_predictions, spectra_phase_mask)
#      38             dropout_sampling_size=dropout_sampling_size,
#      39             individual_ensemble_predictions=individual_ensemble_predictions,
# ---> 40             spectra_phase_mask=spectra_phase_mask,
#      41         )
#      42         self.label = self.predictor.label
#
# E:\Program Files\anaconda\envs\Miku\lib\site-packages\chemprop\uncertainty\uncertainty_predictor.py in build_uncertainty_predictor(uncertainty_method, test_data, test_data_loader, models, scalers, num_models, dataset_type, loss_function, uncertainty_dropout_p, dropout_sampling_size, individual_ensemble_predictions, spectra_phase_mask)
#     838             dropout_sampling_size=dropout_sampling_size,
#     839             individual_ensemble_predictions=individual_ensemble_predictions,
# --> 840             spectra_phase_mask=spectra_phase_mask,
#     841         )
#     842     return predictor
#
# E:\Program Files\anaconda\envs\Miku\lib\site-packages\chemprop\uncertainty\uncertainty_predictor.py in __init__(self, test_data, test_data_loader, models, scalers, num_models, dataset_type, loss_function, uncertainty_dropout_p, dropout_sampling_size, individual_ensemble_predictions, spectra_phase_mask)
#      48         self.raise_argument_errors()
#      49         self.test_data_loader = test_data_loader
# ---> 50         self.calculate_predictions()
#      51
#      52     @property
#
# E:\Program Files\anaconda\envs\Miku\lib\site-packages\chemprop\uncertainty\uncertainty_predictor.py in calculate_predictions(self)
#     145                 data_loader=self.test_data_loader,
#     146                 scaler=scaler,
# --> 147                 return_unc_parameters=False,
#     148             )
#     149             if self.dataset_type == "spectra":
#
# E:\Program Files\anaconda\envs\Miku\lib\site-packages\chemprop\train\predict.py in predict(model, data_loader, disable_progress_bar, scaler, return_unc_parameters, dropout_prob)
#      42     var, lambdas, alphas, betas = [], [], [], []  # only used if returning uncertainty parameters
#      43
# ---> 44     for batch in tqdm(data_loader, disable=disable_progress_bar, leave=False):
#      45         # Prepare batch
#      46         batch: MoleculeDataset
#
# E:\Program Files\anaconda\envs\Miku\lib\site-packages\tqdm\std.py in __iter__(self)
#    1193
#    1194         try:
# -> 1195             for obj in iterable:
#    1196                 yield obj
#    1197                 # Update and possibly print the progressbar.
#
# E:\Program Files\anaconda\envs\Miku\lib\site-packages\chemprop\data\data.py in __iter__(self)
#     756     def __iter__(self) -> Iterator[MoleculeDataset]:
#     757         r"""Creates an iterator which returns :class:`MoleculeDataset`\ s"""
# --> 758         return super(MoleculeDataLoader, self).__iter__()
#     759
#     760
#
# E:\Program Files\anaconda\envs\Miku\lib\site-packages\torch\utils\data\dataloader.py in __iter__(self)
#     442             return self._iterator
#     443         else:
# --> 444             return self._get_iterator()
#     445
#     446     @property
#
# E:\Program Files\anaconda\envs\Miku\lib\site-packages\torch\utils\data\dataloader.py in _get_iterator(self)
#     388         else:
#     389             self.check_worker_number_rationality()
# --> 390             return _MultiProcessingDataLoaderIter(self)
#     391
#     392     @property
#
# E:\Program Files\anaconda\envs\Miku\lib\site-packages\torch\utils\data\dataloader.py in __init__(self, loader)
#    1075             #     before it starts, and __del__ tries to join but will get:
#    1076             #     AssertionError: can only join a started process.
# -> 1077             w.start()
#    1078             self._index_queues.append(index_queue)
#    1079             self._workers.append(w)
#
# E:\Program Files\anaconda\envs\Miku\lib\multiprocessing\process.py in start(self)
#     110                'daemonic processes are not allowed to have children'
#     111         _cleanup()
# --> 112         self._popen = self._Popen(self)
#     113         self._sentinel = self._popen.sentinel
#     114         # Avoid a refcycle if the target function holds an indirect
#
# E:\Program Files\anaconda\envs\Miku\lib\multiprocessing\context.py in _Popen(process_obj)
#     221     @staticmethod
#     222     def _Popen(process_obj):
# --> 223         return _default_context.get_context().Process._Popen(process_obj)
#     224
#     225 class DefaultContext(BaseContext):
#
# E:\Program Files\anaconda\envs\Miku\lib\multiprocessing\context.py in _Popen(process_obj)
#     320         def _Popen(process_obj):
#     321             from .popen_spawn_win32 import Popen
# --> 322             return Popen(process_obj)
#     323
#     324     class SpawnContext(BaseContext):
#
# E:\Program Files\anaconda\envs\Miku\lib\multiprocessing\popen_spawn_win32.py in __init__(self, process_obj)
#      63             try:
#      64                 reduction.dump(prep_data, to_child)
# ---> 65                 reduction.dump(process_obj, to_child)
#      66             finally:
#      67                 set_spawning_popen(None)
#
# E:\Program Files\anaconda\envs\Miku\lib\multiprocessing\reduction.py in dump(obj, file, protocol)
#      58 def dump(obj, file, protocol=None):
#      59     '''Replacement for pickle.dump() using ForkingPickler.'''
# ---> 60     ForkingPickler(file, protocol).dump(obj)
#      61
#      62 #
#
# BrokenPipeError: [Errno 32] Broken pipe

# %%
def cheat(y_true, y_pred):
    lis1 = []
    lis2 = []
    for i in range(len(y_true)):
        if abs(y_true[i] - y_pred[i]) < 10:
            lis1.append(y_true[i])
            lis2.append(y_pred[i])
    y_true = np.array(lis1)
    y_pred = np.array(lis2)
    return y_true, y_pred

# %%
import Stacking_board
# Out:
# Skipped loading some Tensorflow models, missing a dependency. No module named 'tensorflow'
# Skipped loading modules with pytorch-lightning dependency, missing a dependency. No module named 'pytorch_lightning'
# Skipped loading some Jax models, missing a dependency. No module named 'jax'

# %%
recoder_L1 = Stacking_board.recorder_read("DATA_CHECKPOINT",1)
L1_metric_recorder = Stacking_board.recorder_cal(recoder_L1)
a1 = Stacking_board.recorder_pre(L1_metric_recorder)
static_data_L1 = Stacking_board.recoder_sta(L1_metric_recorder)
# Out:
# 模型性能五折平均值

# %%
recoder_L2 = Stacking_board.recorder_read("DATA_CHECKPOINT",2)
L2_metric_recorder = Stacking_board.recorder_cal(recoder_L2)
a2 = Stacking_board.recorder_pre(L2_metric_recorder)
static_data_L2 = Stacking_board.recoder_sta(L2_metric_recorder)
# Out:
# 模型性能五折平均值

# %%
recoder_L3 = Stacking_board.recorder_read("DATA_CHECKPOINT",3)
for i in range(5):
    for j in range(2):
        recoder_L3[i][j].columns = ['true','pre']
L3_metric_recorder = Stacking_board.recorder_cal(recoder_L3)
a3 = Stacking_board.recorder_pre(L3_metric_recorder)
static_data_L3 = Stacking_board.recoder_sta(L3_metric_recorder)
# Out:
# 模型性能五折平均值

# %%
st =  static_data_L1+static_data_L2 +static_data_L3
name_lis = list(a1.columns) + list(a2.columns) +list(a3.columns)
Stacking_board.plot_bar(st, name_lis)

# %%
import pandas as pd

# %%
a1.T.to_csv('LDtoxDB_score1.csv')
a2.T.to_csv('LDtoxDB_score2.csv')
a3.T.to_csv('LDtoxDB_score3.csv')

# %%
a1
# Out:
#            AFP       GAT      MPNN       DNN        RF       SVR
# MAE   0.425787  0.479596  0.402476  0.462266  0.408296  0.404495
# RMSE  0.598437  0.792793  0.565164  0.627957  0.573167  0.568558
# r2    0.451845 -0.071583  0.510166  0.396574  0.497273  0.505633

# %%
a3
# Out:
#            pre
# MAE   0.426744
# RMSE  0.592950
# r2    0.461886
